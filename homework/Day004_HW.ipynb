# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %% [markdown]
# r.text 讀出來的內容為字串型態，json.loads(r.text) 讀出來的內容為 list。

# %%
import requests, json

# %%
r = requests.get('https://api.github.com/events')
print(type(r.text))
r.text
# Out:
# <class 'str'>
# '[{"id":"11037679305","type":"PushEvent","actor":{"id":675910,"login":"awatson1978","display_login":"awatson1978","gravatar_id":"","url":"https://api.github.com/users/awatson1978","avatar_url":"https://avatars.githubusercontent.com/u/675910?"},"repo":{"id":217831648,"name":"symptomatic/node-on-fhir","url":"https://api.github.com/repos/symptomatic/node-on-fhir"},"payload":{"push_id":4369410700,"size":1,"distinct_size":1,"ref":"refs/heads/elliptic-security-fix","head":"637851ab84b2ef65bc4a0c41a5b95e4fcbcbd366","before":"9ad4c9701235dfc6ef91c8a0d85230b1429822ca","commits":[{"sha":"637851ab84b2ef65bc4a0c41a5b95e4fcbcbd366","author":{"email":"awatson1978@gmail.com","name":"Abigail Watson"},"message":"medium resource class","distinct":true,"url":"https://api.github.com/repos/symptomatic/node-on-fhir/commits/637851ab84b2ef65bc4a0c41a5b95e4fcbcbd366"}]},"public":true,"created_at":"2019-12-08T08:18:02Z","org":{"id":18201081,"login":"symptomatic","gravatar_id":"","url":"https://api.github.com/orgs/symptomatic","avatar_url":"https://avatars.githubusercontent.com/u/18201081?"}},{"id":"11037679308","type":"CreateEvent","actor":{"id":28132681,"login":"hyperhiebl","display_login":"hyperhiebl","gravatar_id":"","url":"https://api.github.com/users/hyperhiebl","avatar_url":"https://avatars.githubusercontent.com/u/28132681?"},"repo":{"id":226635849,"name":"hyperhiebl/maxs","url":"https://api.github.com/repos/hyperhiebl/maxs"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-08T08:18:02Z"},{"id":"11037679301","type":"PushEvent","actor":{"id":38223,"login":"snuggs","display_login":"snuggs","gravatar_id":"","url":"https://api.github.com/users/snuggs","avatar_url":"https://avatars.githubusercontent.com/u/38223?"},"repo":{"id":161963061,"name":"devpunks/studio","url":"https://api.github.com/repos/devpunks/studio"},"payload":{"push_id":4369410698,"size":2,"distinct_size":2,"ref":"refs/heads/master","head":"3b09cd7af8748a529afc016cd5f3f6cae2a65557","before":"c601c13a1763aa3e6ebe15ec80e834005bef22db","commits":[{"sha":"1949a5555980a3a00a8acf2184a60cc1c085cb93","author":{"email":"rashaunstovall@gmail.com","name":"Snuggs"},"message":"Add drum synth link","distinct":true,"url":"https://api.github.com/repos/devpunks/studio/commits/1949a5555980a3a00a8acf2184a60cc1c085cb93"},{"sha":"3b09cd7af8748a529afc016cd5f3f6cae2a65557","author":{"email":"rashaunstovall@gmail.com","name":"Snuggs"},"message":"Add Cursus Iteritas review","distinct":true,"url":"https://api.github.com/repos/devpunks/studio/commits/3b09cd7af8748a529afc016cd5f3f6cae2a65557"}]},"public":true,"created_at":"2019-12-08T08:18:02Z","org":{"id":24778990,"login":"devpunks","gravatar_id":"","url":"https://api.github.com/orgs/devpunks","avatar_url":"https://avatars.githubusercontent.com/u/24778990?"}},{"id":"11037679297","type":"PushEvent","actor":{"id":8517910,"login":"LombiqBot","display_login":"LombiqBot","gravatar_id":"","url":"https://api.github.com/users/LombiqBot","avatar_url":"https://avatars.githubusercontent.com/u/8517910?"},"repo":{"id":46594794,"name":"Lombiq/Associativy-Web-Services","url":"https://api.github.com/repos/Lombiq/Associativy-Web-Services"},"payload":{"push_id":4369410695,"size":0,"distinct_size":0,"ref":"refs/heads/orchard-upgrade-1.9.1","head":"0b7b3a1a5edc790c91a7beae2d715ec8859795a4","before":"0b7b3a1a5edc790c91a7beae2d715ec8859795a4","commits":[]},"public":true,"created_at":"2019-12-08T08:18:02Z","org":{"id":8158177,"login":"Lombiq","gravatar_id":"","url":"https://api.github.com/orgs/Lombiq","avatar_url":"https://avatars.githubusercontent.com/u/8158177?"}},{"id":"11037679296","type":"IssueCommentEvent","actor":{"id":1056270,"login":"clienthax","display_login":"clienthax","gravatar_id":"","url":"https://api.github.com/users/clienthax","avatar_url":"https://avatars.githubusercontent.com/u/1056270?"},"repo":{"id":223390405,"name":"xJon/The-1.12.2-Pack","url":"https://api.github.com ...

# %%
print(type(json.loads(r.text)))
json.loads(r.text)
# Out:
# <class 'list'>
# [{'id': '11037679305',
#   'type': 'PushEvent',
#   'actor': {'id': 675910,
#    'login': 'awatson1978',
#    'display_login': 'awatson1978',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/awatson1978',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/675910?'},
#   'repo': {'id': 217831648,
#    'name': 'symptomatic/node-on-fhir',
#    'url': 'https://api.github.com/repos/symptomatic/node-on-fhir'},
#   'payload': {'push_id': 4369410700,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/elliptic-security-fix',
#    'head': '637851ab84b2ef65bc4a0c41a5b95e4fcbcbd366',
#    'before': '9ad4c9701235dfc6ef91c8a0d85230b1429822ca',
#    'commits': [{'sha': '637851ab84b2ef65bc4a0c41a5b95e4fcbcbd366',
#      'author': {'email': 'awatson1978@gmail.com', 'name': 'Abigail Watson'},
#      'message': 'medium resource class',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/symptomatic/node-on-fhir/commits/637851ab84b2ef65bc4a0c41a5b95e4fcbcbd366'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:02Z',
#   'org': {'id': 18201081,
#    'login': 'symptomatic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/symptomatic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18201081?'}},
#  {'id': '11037679308',
#   'type': 'CreateEvent',
#   'actor': {'id': 28132681,
#    'login': 'hyperhiebl',
#    'display_login': 'hyperhiebl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hyperhiebl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28132681?'},
#   'repo': {'id': 226635849,
#    'name': 'hyperhiebl/maxs',
#    'url': 'https://api.github.com/repos/hyperhiebl/maxs'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-08T08:18:02Z'},
#  {'id': '11037679301',
#   'type': 'PushEvent',
#   'actor': {'id': 38223,
#    'login': 'snuggs',
#    'display_login': 'snuggs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/snuggs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38223?'},
#   'repo': {'id': 161963061,
#    'name': 'devpunks/studio',
#    'url': 'https://api.github.com/repos/devpunks/studio'},
#   'payload': {'push_id': 4369410698,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '3b09cd7af8748a529afc016cd5f3f6cae2a65557',
#    'before': 'c601c13a1763aa3e6ebe15ec80e834005bef22db',
#    'commits': [{'sha': '1949a5555980a3a00a8acf2184a60cc1c085cb93',
#      'author': {'email': 'rashaunstovall@gmail.com', 'name': 'Snuggs'},
#      'message': 'Add drum synth link',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/devpunks/studio/commits/1949a5555980a3a00a8acf2184a60cc1c085cb93'},
#     {'sha': '3b09cd7af8748a529afc016cd5f3f6cae2a65557',
#      'author': {'email': 'rashaunstovall@gmail.com', 'name': 'Snuggs'},
#      'message': 'Add Cursus Iteritas review',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/devpunks/studio/commits/3b09cd7af8748a529afc016cd5f3f6cae2a65557'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:02Z',
#   'org': {'id': 24778990,
#    'login': 'devpunks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/devpunks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24778990?'}},
#  {'id': '11037679297',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46594794,
#    'name': 'Lombiq/Associativy-Web-Services',
#    'url': 'https://api.github.com/repos/Lombiq/Associativy-Web-Services'},
#   'payload': {'push_id': 4369410695,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.9.1',
#    'head': '0b7b3a1a5edc790c91a7beae2d715ec8859795a4',
#    'before': '0b7b3a1a5edc790c91a7beae2d715ec8859795a4',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-08T08:18:02Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11037679296',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1056270,
#    'login': 'clienthax',
#    'display_login': 'clienthax',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/clienthax',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1056270?'},
#   'repo': {'id': 223390405,
#    'name': 'xJon/The-1.12.2-Pack',
#    'url': 'https://api.github.com/repos/xJon/The-1.12.2-Pack'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/xJon/The-1.12.2-Pack/issues/13',
#     'repository_url': 'https://api.github.com/repos/xJon/The-1.12.2-Pack',
#     'labels_url': 'https://api.github.com/repos/xJon/The-1.12.2-Pack/issues/13/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/xJon/The-1.12.2-Pack/issues/13/comments',
#     'events_url': 'https://api.github.com/repos/xJon/The-1.12.2-Pack/issues/13/events',
#     'html_url': 'https://github.com/xJon/The-1.12.2-Pack/issues/13',
#     'id': 530757482,
#     'node_id': 'MDU6SXNzdWU1MzA3NTc0ODI=',
#     'number': 13,
#     'title': 'Botania Bug',
#     'user': {'login': 'Moicut',
#      'id': 42399184,
#      'node_id': 'MDQ6VXNlcjQyMzk5MTg0',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/42399184?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Moicut',
#      'html_url': 'https://github.com/Moicut',
#      'followers_url': 'https://api.github.com/users/Moicut/followers',
#      'following_url': 'https://api.github.com/users/Moicut/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Moicut/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Moicut/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Moicut/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Moicut/orgs',
#      'repos_url': 'https://api.github.com/users/Moicut/repos',
#      'events_url': 'https://api.github.com/users/Moicut/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Moicut/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1691936989,
#       'node_id': 'MDU6TGFiZWwxNjkxOTM2OTg5',
#       'url': 'https://api.github.com/repos/xJon/The-1.12.2-Pack/labels/bug',
#       'name': 'bug',
#       'color': 'd73a4a',
#       'default': True,
#       'description': "Something isn't working"}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2019-12-01T16:31:32Z',
#     'updated_at': '2019-12-08T08:18:01Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'Are you using the latest/recommended version of the modpack without any major additional mods:\r\nyes\r\n\r\nAre you using a computer with 8GB or more of RAM? ([How to check]\r\nyes\r\n\r\nAre you using Java 8, 64-bit?\r\nyes\r\n\r\nIs the modpack crashing: yes, but not a software crash, I just get a ingame alert saying it has crashed\r\n\r\nIs Optifine installed or any other additional mods: no\r\n\r\nDescribe the issue\r\nA clear and concise description of what the issue is.\r\nAny time I try and go onto a server I have, the modpack, I get this crash link and a error that says Botania\r\nhttps://paste.dimdev.org/wuluwurupa.mccrash'},
#    'comment': {'url': 'https://api.github.com/repos/xJon/The-1.12.2-Pack/issues/comments/562923344',
#     'html_url': 'https://github.com/xJon/The-1.12.2-Pack/issues/13#issuecomment-562923344',
#     'issue_url': 'https://api.github.com/repos/xJon/The-1.12.2-Pack/issues/13',
#     'id': 562923344,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MjkyMzM0NA==',
#     'user': {'login': 'clienthax',
#      'id': 1056270,
#      'node_id': 'MDQ6VXNlcjEwNTYyNzA=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/1056270?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/clienthax',
#      'html_url': 'https://github.com/clienthax',
#      'followers_url': 'https://api.github.com/users/clienthax/followers',
#      'following_url': 'https://api.github.com/users/clienthax/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/clienthax/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/clienthax/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/clienthax/subscriptions',
#      'organizations_url': 'https://api.github.com/users/clienthax/orgs',
#      'repos_url': 'https://api.github.com/users/clienthax/repos',
#      'events_url': 'https://api.github.com/users/clienthax/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/clienthax/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-08T08:18:01Z',
#     'updated_at': '2019-12-08T08:18:01Z',
#     'author_association': 'NONE',
#     'body': 'By any chance were you using a digiminer in the area?'}},
#   'public': True,
#   'created_at': '2019-12-08T08:18:02Z'},
#  {'id': '11037679293',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 58648817,
#    'login': 'daisuke0311',
#    'display_login': 'daisuke0311',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/daisuke0311',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58648817?'},
#   'repo': {'id': 226626320,
#    'name': 'daisuke0311/git-app',
#    'url': 'https://api.github.com/repos/daisuke0311/git-app'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/daisuke0311/git-app/issues/1',
#     'repository_url': 'https://api.github.com/repos/daisuke0311/git-app',
#     'labels_url': 'https://api.github.com/repos/daisuke0311/git-app/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/daisuke0311/git-app/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/daisuke0311/git-app/issues/1/events',
#     'html_url': 'https://github.com/daisuke0311/git-app/pull/1',
#     'id': 534505764,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzUwMzg2MzE5',
#     'number': 1,
#     'title': '記事投稿機能の実装',
#     'user': {'login': 'daisuke0311',
#      'id': 58648817,
#      'node_id': 'MDQ6VXNlcjU4NjQ4ODE3',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/58648817?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/daisuke0311',
#      'html_url': 'https://github.com/daisuke0311',
#      'followers_url': 'https://api.github.com/users/daisuke0311/followers',
#      'following_url': 'https://api.github.com/users/daisuke0311/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/daisuke0311/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/daisuke0311/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/daisuke0311/subscriptions',
#      'organizations_url': 'https://api.github.com/users/daisuke0311/orgs',
#      'repos_url': 'https://api.github.com/users/daisuke0311/repos',
#      'events_url': 'https://api.github.com/users/daisuke0311/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/daisuke0311/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-12-08T07:50:40Z',
#     'updated_at': '2019-12-08T08:18:02Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'pull_request': {'url': 'https://api.github.com/repos/daisuke0311/git-app/pulls/1',
#      'html_url': 'https://github.com/daisuke0311/git-app/pull/1',
#      'diff_url': 'https://github.com/daisuke0311/git-app/pull/1.diff',
#      'patch_url': 'https://github.com/daisuke0311/git-app/pull/1.patch'},
#     'body': '#what\r\n記事投稿機能を実装する。railsのscaffoldを用いて、articleモデルを作成し、titleカラム、authorカラム、textカラムを作成した。\r\n\r\n#why\r\n記事投稿機能は本アプリケーションの根幹機能であるため。'},
#    'comment': {'url': 'https://api.github.com/repos/daisuke0311/git-app/issues/comments/562923345',
#     'html_url': 'https://github.com/daisuke0311/git-app/pull/1#issuecomment-562923345',
#     'issue_url': 'https://api.github.com/repos/daisuke0311/git-app/issues/1',
#     'id': 562923345,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MjkyMzM0NQ==',
#     'user': {'login': 'daisuke0311',
#      'id': 58648817,
#      'node_id': 'MDQ6VXNlcjU4NjQ4ODE3',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/58648817?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/daisuke0311',
#      'html_url': 'https://github.com/daisuke0311',
#      'followers_url': 'https://api.github.com/users/daisuke0311/followers',
#      'following_url': 'https://api.github.com/users/daisuke0311/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/daisuke0311/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/daisuke0311/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/daisuke0311/subscriptions',
#      'organizations_url': 'https://api.github.com/users/daisuke0311/orgs',
#      'repos_url': 'https://api.github.com/users/daisuke0311/repos',
#      'events_url': 'https://api.github.com/users/daisuke0311/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/daisuke0311/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-08T08:18:02Z',
#     'updated_at': '2019-12-08T08:18:02Z',
#     'author_association': 'OWNER',
#     'body': '不要なファイル、コメントアウトがあれば削除しましょう。'}},
#   'public': True,
#   'created_at': '2019-12-08T08:18:02Z'},
#  {'id': '11037679286',
#   'type': 'PushEvent',
#   'actor': {'id': 58461715,
#    'login': 'AdamWeatherby',
#    'display_login': 'AdamWeatherby',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AdamWeatherby',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58461715?'},
#   'repo': {'id': 225561179,
#    'name': 'AdamWeatherby/AdamWeatherby.github.io',
#    'url': 'https://api.github.com/repos/AdamWeatherby/AdamWeatherby.github.io'},
#   'payload': {'push_id': 4369410690,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9fdd0a0f6063e6de79167b181dc08fde10f45512',
#    'before': '1ba8e99f271a523d581af359e27c91f6b9400f89',
#    'commits': [{'sha': '9fdd0a0f6063e6de79167b181dc08fde10f45512',
#      'author': {'email': 'adamwproductions@gmail.com',
#       'name': 'AdamWeatherby'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AdamWeatherby/AdamWeatherby.github.io/commits/9fdd0a0f6063e6de79167b181dc08fde10f45512'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:01Z'},
#  {'id': '11037679287',
#   'type': 'DeleteEvent',
#   'actor': {'id': 58599015,
#    'login': 'CapricoinPlus',
#    'display_login': 'CapricoinPlus',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CapricoinPlus',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58599015?'},
#   'repo': {'id': 226633217,
#    'name': 'Capricoinofficial/capricoinplus-core',
#    'url': 'https://api.github.com/repos/Capricoinofficial/capricoinplus-core'},
#   'payload': {'ref': 'v0.18.1.1.0', 'ref_type': 'tag', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-08T08:18:01Z',
#   'org': {'id': 13353250,
#    'login': 'Capricoinofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Capricoinofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13353250?'}},
#  {'id': '11037679283',
#   'type': 'PushEvent',
#   'actor': {'id': 11209408,
#    'login': 'KaiMohr',
#    'display_login': 'KaiMohr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KaiMohr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11209408?'},
#   'repo': {'id': 225106634,
#    'name': 'KaiMohr/json_lib',
#    'url': 'https://api.github.com/repos/KaiMohr/json_lib'},
#   'payload': {'push_id': 4369410689,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cac8d17c45be94c8d70e51ffc9c4811243adea71',
#    'before': 'cd505eaa1964f3ca9826bf1f620683bfb36e38aa',
#    'commits': [{'sha': 'cac8d17c45be94c8d70e51ffc9c4811243adea71',
#      'author': {'email': 'tvmonk@arcor.de', 'name': 'KaiMohr'},
#      'message': 'film logo added',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/KaiMohr/json_lib/commits/cac8d17c45be94c8d70e51ffc9c4811243adea71'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:01Z'},
#  {'id': '11037679284',
#   'type': 'PushEvent',
#   'actor': {'id': 1065481,
#    'login': 'gwendallg',
#    'display_login': 'gwendallg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gwendallg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1065481?'},
#   'repo': {'id': 206824257,
#    'name': 'AdventielFr/terraform-aws-bastion',
#    'url': 'https://api.github.com/repos/AdventielFr/terraform-aws-bastion'},
#   'payload': {'push_id': 4369410688,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': '7a12e62beb9b25e21726766fb8e95a9135aa2f43',
#    'before': '04d75c4ff956d6bbaa1cd46e4d2a73ff16014684',
#    'commits': [{'sha': '7a12e62beb9b25e21726766fb8e95a9135aa2f43',
#      'author': {'email': 'gwendallgarnier@MacBook-Pro-de-Gwendall.local',
#       'name': 'Gwendall Garnier'},
#      'message': 'feat: add lambda bastion-find-and-remove-expired-ssh-keys',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AdventielFr/terraform-aws-bastion/commits/7a12e62beb9b25e21726766fb8e95a9135aa2f43'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:01Z',
#   'org': {'id': 20702827,
#    'login': 'AdventielFr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/AdventielFr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20702827?'}},
#  {'id': '11037679277',
#   'type': 'PushEvent',
#   'actor': {'id': 13098888,
#    'login': 'mvanbeusekom',
#    'display_login': 'mvanbeusekom',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mvanbeusekom',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13098888?'},
#   'repo': {'id': 212069952,
#    'name': 'Baseflow/livestock',
#    'url': 'https://api.github.com/repos/Baseflow/livestock'},
#   'payload': {'push_id': 4369410681,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': '9dd3371ac46f8b8c380c206aaca529c2ff942358',
#    'before': 'fcc539ca13642e40cc9418524c1ea074be348945',
#    'commits': [{'sha': '9dd3371ac46f8b8c380c206aaca529c2ff942358',
#      'author': {'email': 'maurits@baseflow.com',
#       'name': 'Maurits van Beusekom'},
#      'message': 'Fix warnings',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Baseflow/livestock/commits/9dd3371ac46f8b8c380c206aaca529c2ff942358'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:01Z',
#   'org': {'id': 37274346,
#    'login': 'Baseflow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Baseflow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37274346?'}},
#  {'id': '11037679278',
#   'type': 'PushEvent',
#   'actor': {'id': 57587965,
#    'login': 'aguilarbrian10',
#    'display_login': 'aguilarbrian10',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aguilarbrian10',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57587965?'},
#   'repo': {'id': 225013754,
#    'name': 'aguilarbrian10/Machine-Problem',
#    'url': 'https://api.github.com/repos/aguilarbrian10/Machine-Problem'},
#   'payload': {'push_id': 4369410683,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e0630b8ed0e39b5f855d17887f9bf45a2cd5d9dd',
#    'before': 'b29b4cdecac03016249396001a3a346cf3d96416',
#    'commits': [{'sha': 'e0630b8ed0e39b5f855d17887f9bf45a2cd5d9dd',
#      'author': {'email': '57587965+aguilarbrian10@users.noreply.github.com',
#       'name': 'aguilarbrian10'},
#      'message': 'Update Problem 2.1 (Matlab)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aguilarbrian10/Machine-Problem/commits/e0630b8ed0e39b5f855d17887f9bf45a2cd5d9dd'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:01Z'},
#  {'id': '11037679275',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 58297469,
#    'login': 'veronica-hu',
#    'display_login': 'veronica-hu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/veronica-hu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58297469?'},
#   'repo': {'id': 224757623,
#    'name': 'veronica-hu/ICS-pro',
#    'url': 'https://api.github.com/repos/veronica-hu/ICS-pro'},
#   'payload': {'action': 'opened',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/veronica-hu/ICS-pro/pulls/3',
#     'id': 350388164,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzUwMzg4MTY0',
#     'html_url': 'https://github.com/veronica-hu/ICS-pro/pull/3',
#     'diff_url': 'https://github.com/veronica-hu/ICS-pro/pull/3.diff',
#     'patch_url': 'https://github.com/veronica-hu/ICS-pro/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/issues/3',
#     'number': 3,
#     'state': 'open',
#     'locked': False,
#     'title': 'Add files via upload',
#     'user': {'login': 'veronica-hu',
#      'id': 58297469,
#      'node_id': 'MDQ6VXNlcjU4Mjk3NDY5',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/58297469?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/veronica-hu',
#      'html_url': 'https://github.com/veronica-hu',
#      'followers_url': 'https://api.github.com/users/veronica-hu/followers',
#      'following_url': 'https://api.github.com/users/veronica-hu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/veronica-hu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/veronica-hu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/veronica-hu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/veronica-hu/orgs',
#      'repos_url': 'https://api.github.com/users/veronica-hu/repos',
#      'events_url': 'https://api.github.com/users/veronica-hu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/veronica-hu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-12-08T08:18:01Z',
#     'updated_at': '2019-12-08T08:18:01Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/statuses/75bf6ef94c8c4ec348ca1df1fcb6141b140c234a',
#     'head': {'label': 'veronica-hu:自带',
#      'ref': '自带',
#      'sha': '75bf6ef94c8c4ec348ca1df1fcb6141b140c234a',
#      'user': {'login': 'veronica-hu',
#       'id': 58297469,
#       'node_id': 'MDQ6VXNlcjU4Mjk3NDY5',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/58297469?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/veronica-hu',
#       'html_url': 'https://github.com/veronica-hu',
#       'followers_url': 'https://api.github.com/users/veronica-hu/followers',
#       'following_url': 'https://api.github.com/users/veronica-hu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/veronica-hu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/veronica-hu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/veronica-hu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/veronica-hu/orgs',
#       'repos_url': 'https://api.github.com/users/veronica-hu/repos',
#       'events_url': 'https://api.github.com/users/veronica-hu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/veronica-hu/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 224757623,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ3NTc2MjM=',
#       'name': 'ICS-pro',
#       'full_name': 'veronica-hu/ICS-pro',
#       'private': False,
#       'owner': {'login': 'veronica-hu',
#        'id': 58297469,
#        'node_id': 'MDQ6VXNlcjU4Mjk3NDY5',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/58297469?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/veronica-hu',
#        'html_url': 'https://github.com/veronica-hu',
#        'followers_url': 'https://api.github.com/users/veronica-hu/followers',
#        'following_url': 'https://api.github.com/users/veronica-hu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/veronica-hu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/veronica-hu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/veronica-hu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/veronica-hu/orgs',
#        'repos_url': 'https://api.github.com/users/veronica-hu/repos',
#        'events_url': 'https://api.github.com/users/veronica-hu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/veronica-hu/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/veronica-hu/ICS-pro',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/veronica-hu/ICS-pro',
#       'forks_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/forks',
#       'keys_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/teams',
#       'hooks_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/hooks',
#       'issue_events_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/events',
#       'assignees_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/tags',
#       'blobs_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/languages',
#       'stargazers_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/stargazers',
#       'contributors_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/contributors',
#       'subscribers_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/subscribers',
#       'subscription_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/subscription',
#       'commits_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/merges',
#       'archive_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/downloads',
#       'issues_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/deployments',
#       'created_at': '2019-11-29T01:53:27Z',
#       'updated_at': '2019-12-08T08:15:20Z',
#       'pushed_at': '2019-12-08T08:17:49Z',
#       'git_url': 'git://github.com/veronica-hu/ICS-pro.git',
#       'ssh_url': 'git@github.com:veronica-hu/ICS-pro.git',
#       'clone_url': 'https://github.com/veronica-hu/ICS-pro.git',
#       'svn_url': 'https://github.com/veronica-hu/ICS-pro',
#       'homepage': None,
#       'size': 5,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 1,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'veronica-hu:master',
#      'ref': 'master',
#      'sha': '44bbaaff0110fe09c384960ccdf544ee4683062f',
#      'user': {'login': 'veronica-hu',
#       'id': 58297469,
#       'node_id': 'MDQ6VXNlcjU4Mjk3NDY5',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/58297469?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/veronica-hu',
#       'html_url': 'https://github.com/veronica-hu',
#       'followers_url': 'https://api.github.com/users/veronica-hu/followers',
#       'following_url': 'https://api.github.com/users/veronica-hu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/veronica-hu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/veronica-hu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/veronica-hu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/veronica-hu/orgs',
#       'repos_url': 'https://api.github.com/users/veronica-hu/repos',
#       'events_url': 'https://api.github.com/users/veronica-hu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/veronica-hu/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 224757623,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ3NTc2MjM=',
#       'name': 'ICS-pro',
#       'full_name': 'veronica-hu/ICS-pro',
#       'private': False,
#       'owner': {'login': 'veronica-hu',
#        'id': 58297469,
#        'node_id': 'MDQ6VXNlcjU4Mjk3NDY5',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/58297469?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/veronica-hu',
#        'html_url': 'https://github.com/veronica-hu',
#        'followers_url': 'https://api.github.com/users/veronica-hu/followers',
#        'following_url': 'https://api.github.com/users/veronica-hu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/veronica-hu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/veronica-hu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/veronica-hu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/veronica-hu/orgs',
#        'repos_url': 'https://api.github.com/users/veronica-hu/repos',
#        'events_url': 'https://api.github.com/users/veronica-hu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/veronica-hu/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/veronica-hu/ICS-pro',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/veronica-hu/ICS-pro',
#       'forks_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/forks',
#       'keys_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/teams',
#       'hooks_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/hooks',
#       'issue_events_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/events',
#       'assignees_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/tags',
#       'blobs_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/languages',
#       'stargazers_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/stargazers',
#       'contributors_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/contributors',
#       'subscribers_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/subscribers',
#       'subscription_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/subscription',
#       'commits_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/merges',
#       'archive_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/downloads',
#       'issues_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/veronica-hu/ICS-pro/deployments',
#       'created_at': '2019-11-29T01:53:27Z',
#       'updated_at': '2019-12-08T08:15:20Z',
#       'pushed_at': '2019-12-08T08:17:49Z',
#       'git_url': 'git://github.com/veronica-hu/ICS-pro.git',
#       'ssh_url': 'git@github.com:veronica-hu/ICS-pro.git',
#       'clone_url': 'https://github.com/veronica-hu/ICS-pro.git',
#       'svn_url': 'https://github.com/veronica-hu/ICS-pro',
#       'homepage': None,
#       'size': 5,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 1,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/veronica-hu/ICS-pro/pulls/3'},
#      'html': {'href': 'https://github.com/veronica-hu/ICS-pro/pull/3'},
#      'issue': {'href': 'https://api.github.com/repos/veronica-hu/ICS-pro/issues/3'},
#      'comments': {'href': 'https://api.github.com/repos/veronica-hu/ICS-pro/issues/3/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/veronica-hu/ICS-pro/pulls/3/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/veronica-hu/ICS-pro/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/veronica-hu/ICS-pro/pulls/3/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/veronica-hu/ICS-pro/statuses/75bf6ef94c8c4ec348ca1df1fcb6141b140c234a'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 2670,
#     'deletions': 0,
#     'changed_files': 6}},
#   'public': True,
#   'created_at': '2019-12-08T08:18:01Z'},
#  {'id': '11037679274',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 29172177,
#    'login': 'onsd',
#    'display_login': 'onsd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/onsd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29172177?'},
#   'repo': {'id': 196011816,
#    'name': 'SECHACK-Z/reverse-proxy',
#    'url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/pulls/comments/355168234',
#     'pull_request_review_id': 328593886,
#     'id': 355168234,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM1NTE2ODIzNA==',
#     'diff_hunk': '@@ -0,0 +1,110 @@\n+package cd\n+\n+import (\n+\t"context"\n+\t"fmt"\n+\t"main/pubsub"\n+\t"main/pubsub/systemevent"\n+\t"os"\n+\t"os/exec"\n+\t"strings"\n+\t"time"\n+\n+\t"github.com/jinzhu/gorm"\n+)\n+\n+type CDManager struct {\n+\tdb             *gorm.DB\n+\ttargetContexts []targetContext\n+}\n+\n+type targetContext struct {\n+\trepository string\n+\tname       string\n+\tctx        context.Context\n+\tcanselFunc context.CancelFunc\n+}\n+\n+func New(db *gorm.DB) *CDManager {\n+\tdb.AutoMigrate()\n+\tcdManager := &CDManager{db: db}\n+\tpubsub.GetWebookEvent.Sub(cdManager.onGetWebhook)\n+\treturn cdManager\n+}\n+\n+func (m *CDManager) onGetWebhook(getWebhook pubsub.GetWebook) {\n+\trepository := getWebhook.Repository\n+\tfor index, targetContext := range m.targetContexts {\n+\t\tif targetContext.repository == repository {\n+\t\t\ttargetContext.canselFunc()\n+\t\t\t// remove from slice\n+\t\t\tm.targetContexts = append(m.targetContexts[:index], m.targetContexts[index+1:]...)\n+\t\t}\n+\t}\n+\tpath := strings.Split(getWebhook.Repository, "/")\n+\tnewContext := targetContext{\n+\t\trepository: getWebhook.Repository,\n+\t\tname:       path[len(path)-1],\n+\t\tctx:        context.Background(),\n+\t\tcanselFunc: func() {},\n+\t}\n+\tctx, cancelFunc := context.WithCancel(context.Background())\n+\tnewContext.ctx = ctx\n+\tnewContext.canselFunc = cancelFunc',
#     'path': 'server/manager/cd/cd.go',
#     'position': None,
#     'original_position': 53,
#     'commit_id': '0bd46ca1c702e2092da929332bca9f5c055dfba1',
#     'original_commit_id': 'db59039fdc2576e498e76f6d36ccb75072a9750d',
#     'user': {'login': 'onsd',
#      'id': 29172177,
#      'node_id': 'MDQ6VXNlcjI5MTcyMTc3',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/29172177?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/onsd',
#      'html_url': 'https://github.com/onsd',
#      'followers_url': 'https://api.github.com/users/onsd/followers',
#      'following_url': 'https://api.github.com/users/onsd/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/onsd/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/onsd/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/onsd/subscriptions',
#      'organizations_url': 'https://api.github.com/users/onsd/orgs',
#      'repos_url': 'https://api.github.com/users/onsd/repos',
#      'events_url': 'https://api.github.com/users/onsd/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/onsd/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '寝たら`map[string]string` の意味がわかったのでfix',
#     'created_at': '2019-12-08T08:18:00Z',
#     'updated_at': '2019-12-08T08:18:01Z',
#     'html_url': 'https://github.com/SECHACK-Z/reverse-proxy/pull/53#discussion_r355168234',
#     'pull_request_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/pulls/53',
#     'author_association': 'COLLABORATOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/pulls/comments/355168234'},
#      'html': {'href': 'https://github.com/SECHACK-Z/reverse-proxy/pull/53#discussion_r355168234'},
#      'pull_request': {'href': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/pulls/53'}},
#     'in_reply_to_id': 355128681},
#    'pull_request': {'url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/pulls/53',
#     'id': 350319599,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzUwMzE5NTk5',
#     'html_url': 'https://github.com/SECHACK-Z/reverse-proxy/pull/53',
#     'diff_url': 'https://github.com/SECHACK-Z/reverse-proxy/pull/53.diff',
#     'patch_url': 'https://github.com/SECHACK-Z/reverse-proxy/pull/53.patch',
#     'issue_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/issues/53',
#     'number': 53,
#     'state': 'open',
#     'locked': False,
#     'title': 'CDの実装',
#     'user': {'login': 'onsd',
#      'id': 29172177,
#      'node_id': 'MDQ6VXNlcjI5MTcyMTc3',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/29172177?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/onsd',
#      'html_url': 'https://github.com/onsd',
#      'followers_url': 'https://api.github.com/users/onsd/followers',
#      'following_url': 'https://api.github.com/users/onsd/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/onsd/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/onsd/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/onsd/subscriptions',
#      'organizations_url': 'https://api.github.com/users/onsd/orgs',
#      'repos_url': 'https://api.github.com/users/onsd/repos',
#      'events_url': 'https://api.github.com/users/onsd/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/onsd/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'CDを実装\r\n1. 起動時に`git clone`, `go build -o main`, `./main`する\r\n2. githubからwebhookを受けて、`master`へのpushだった場合 `git pull`, `go build -o main`, `./main`する\r\n\r\n',
#     'created_at': '2019-12-07T15:21:28Z',
#     'updated_at': '2019-12-08T08:18:01Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '9e91c93fba90a5fbef30cdd244076fb295cb80cd',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/pulls/53/commits',
#     'review_comments_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/pulls/53/comments',
#     'review_comment_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/issues/53/comments',
#     'statuses_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/statuses/0bd46ca1c702e2092da929332bca9f5c055dfba1',
#     'head': {'label': 'SECHACK-Z:feature/CD',
#      'ref': 'feature/CD',
#      'sha': '0bd46ca1c702e2092da929332bca9f5c055dfba1',
#      'user': {'login': 'SECHACK-Z',
#       'id': 55144100,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1MTQ0MTAw',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/55144100?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SECHACK-Z',
#       'html_url': 'https://github.com/SECHACK-Z',
#       'followers_url': 'https://api.github.com/users/SECHACK-Z/followers',
#       'following_url': 'https://api.github.com/users/SECHACK-Z/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SECHACK-Z/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SECHACK-Z/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SECHACK-Z/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SECHACK-Z/orgs',
#       'repos_url': 'https://api.github.com/users/SECHACK-Z/repos',
#       'events_url': 'https://api.github.com/users/SECHACK-Z/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SECHACK-Z/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 196011816,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTYwMTE4MTY=',
#       'name': 'reverse-proxy',
#       'full_name': 'SECHACK-Z/reverse-proxy',
#       'private': False,
#       'owner': {'login': 'SECHACK-Z',
#        'id': 55144100,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1MTQ0MTAw',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/55144100?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/SECHACK-Z',
#        'html_url': 'https://github.com/SECHACK-Z',
#        'followers_url': 'https://api.github.com/users/SECHACK-Z/followers',
#        'following_url': 'https://api.github.com/users/SECHACK-Z/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/SECHACK-Z/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/SECHACK-Z/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/SECHACK-Z/subscriptions',
#        'organizations_url': 'https://api.github.com/users/SECHACK-Z/orgs',
#        'repos_url': 'https://api.github.com/users/SECHACK-Z/repos',
#        'events_url': 'https://api.github.com/users/SECHACK-Z/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/SECHACK-Z/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/SECHACK-Z/reverse-proxy',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy',
#       'forks_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/forks',
#       'keys_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/teams',
#       'hooks_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/hooks',
#       'issue_events_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/events',
#       'assignees_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/SECHACK-Z/reverse-proxy/tags',
# ...
#       'languages_url': 'https://api.github.com/repos/leedavid/QTggchess/languages',
#       'stargazers_url': 'https://api.github.com/repos/leedavid/QTggchess/stargazers',
#       'contributors_url': 'https://api.github.com/repos/leedavid/QTggchess/contributors',
#       'subscribers_url': 'https://api.github.com/repos/leedavid/QTggchess/subscribers',
#       'subscription_url': 'https://api.github.com/repos/leedavid/QTggchess/subscription',
#       'commits_url': 'https://api.github.com/repos/leedavid/QTggchess/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/leedavid/QTggchess/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/leedavid/QTggchess/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/leedavid/QTggchess/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/leedavid/QTggchess/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/leedavid/QTggchess/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/leedavid/QTggchess/merges',
#       'archive_url': 'https://api.github.com/repos/leedavid/QTggchess/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/leedavid/QTggchess/downloads',
#       'issues_url': 'https://api.github.com/repos/leedavid/QTggchess/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/leedavid/QTggchess/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/leedavid/QTggchess/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/leedavid/QTggchess/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/leedavid/QTggchess/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/leedavid/QTggchess/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/leedavid/QTggchess/deployments',
#       'created_at': '2019-10-06T00:29:30Z',
#       'updated_at': '2019-12-07T23:20:05Z',
#       'pushed_at': '2019-12-07T12:32:59Z',
#       'git_url': 'git://github.com/leedavid/QTggchess.git',
#       'ssh_url': 'git@github.com:leedavid/QTggchess.git',
#       'clone_url': 'https://github.com/leedavid/QTggchess.git',
#       'svn_url': 'https://github.com/leedavid/QTggchess',
#       'homepage': None,
#       'size': 30169,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 1,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/leedavid/QTggchess/pulls/1'},
#      'html': {'href': 'https://github.com/leedavid/QTggchess/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/leedavid/QTggchess/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/leedavid/QTggchess/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/leedavid/QTggchess/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/leedavid/QTggchess/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/leedavid/QTggchess/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/leedavid/QTggchess/statuses/47ca3180ebec118c37cab3fed03859e26ea6f9e5'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 39,
#     'deletions': 44,
#     'changed_files': 4}},
#   'public': True,
#   'created_at': '2019-12-08T08:18:01Z'},
#  {'id': '11037679263',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46594396,
#    'name': 'Lombiq/Associativy-Notions-Demo-Instance',
#    'url': 'https://api.github.com/repos/Lombiq/Associativy-Notions-Demo-Instance'},
#   'payload': {'push_id': 4369410673,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/dev',
#    'head': '04aaf82cb14277a3355818815cc99541cdff7005',
#    'before': '04aaf82cb14277a3355818815cc99541cdff7005',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-08T08:18:01Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11037679262',
#   'type': 'PushEvent',
#   'actor': {'id': 34169986,
#    'login': 'pawdon',
#    'display_login': 'pawdon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pawdon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34169986?'},
#   'repo': {'id': 216158751,
#    'name': 'pawdon/python_course',
#    'url': 'https://api.github.com/repos/pawdon/python_course'},
#   'payload': {'push_id': 4369410672,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9f8cc6af1edc64f8223e73bfce6b143e7885e164',
#    'before': 'e5af93ffe95ab31e6cd925167ce34c51879be88f',
#    'commits': [{'sha': '9f8cc6af1edc64f8223e73bfce6b143e7885e164',
#      'author': {'email': 'pawdonapi@gmail.com', 'name': 'pawdon'},
#      'message': 'GUI',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pawdon/python_course/commits/9f8cc6af1edc64f8223e73bfce6b143e7885e164'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:01Z'},
#  {'id': '11037679261',
#   'type': 'PushEvent',
#   'actor': {'id': 23304049,
#    'login': 'xiaofengbai',
#    'display_login': 'xiaofengbai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xiaofengbai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23304049?'},
#   'repo': {'id': 224395519,
#    'name': 'xiaofengbai/shop',
#    'url': 'https://api.github.com/repos/xiaofengbai/shop'},
#   'payload': {'push_id': 4369410671,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3d49ad79ae851d186cbbb505a02638f7ff6afc31',
#    'before': '657342228574fff969c1e0f10a53eb65d07602fe',
#    'commits': [{'sha': '3d49ad79ae851d186cbbb505a02638f7ff6afc31',
#      'author': {'email': 'byf20222@163.com', 'name': 'xiaofengbai'},
#      'message': 'init',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xiaofengbai/shop/commits/3d49ad79ae851d186cbbb505a02638f7ff6afc31'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:00Z'},
#  {'id': '11037679260',
#   'type': 'PushEvent',
#   'actor': {'id': 26905475,
#    'login': 'sardarnaqib',
#    'display_login': 'sardarnaqib',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sardarnaqib',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26905475?'},
#   'repo': {'id': 226625420,
#    'name': 'sardarnaqib/restoIstanbul',
#    'url': 'https://api.github.com/repos/sardarnaqib/restoIstanbul'},
#   'payload': {'push_id': 4369410670,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '579582b7508efbba9f6516663b70df2c49f3d104',
#    'before': '7d8d7af1bcc9b133e610dc491a3bf70fe56544bd',
#    'commits': [{'sha': '579582b7508efbba9f6516663b70df2c49f3d104',
#      'author': {'email': 'sarkhan.naqib@gmail.com', 'name': 'Sardar Khan'},
#      'message': 'Added new button in home redirecting to ubereats restaurant page',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sardarnaqib/restoIstanbul/commits/579582b7508efbba9f6516663b70df2c49f3d104'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:00Z'},
#  {'id': '11037679250',
#   'type': 'PushEvent',
#   'actor': {'id': 17193977,
#    'login': 'newstools',
#    'display_login': 'newstools',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/newstools',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17193977?'},
#   'repo': {'id': 202102108,
#    'name': 'newstools/2019-vanguard-nigeria',
#    'url': 'https://api.github.com/repos/newstools/2019-vanguard-nigeria'},
#   'payload': {'push_id': 4369410665,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9b63c22d92b6e448309bf2195a7943e308f215dd',
#    'before': '1867a0764a3da46a2774a30605830d0982607869',
#    'commits': [{'sha': '9b63c22d92b6e448309bf2195a7943e308f215dd',
#      'author': {'email': 'github@newstools.co.za', 'name': 'NewsTools'},
#      'message': 'Created Text For URL [www.vanguardngr.com/2019/12/no-alternative-to-30bn-loan-ben-akabueze-dg-budget-office/]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/newstools/2019-vanguard-nigeria/commits/9b63c22d92b6e448309bf2195a7943e308f215dd'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:00Z'},
#  {'id': '11037679252',
#   'type': 'PushEvent',
#   'actor': {'id': 54149147,
#    'login': 'Stiles-X',
#    'display_login': 'Stiles-X',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Stiles-X',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54149147?'},
#   'repo': {'id': 226154121,
#    'name': 'Stiles-X/console-menu',
#    'url': 'https://api.github.com/repos/Stiles-X/console-menu'},
#   'payload': {'push_id': 4369410667,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/beta',
#    'head': 'f79c082cd1445a8ec4dcda3603018fbbbcef4ca3',
#    'before': '56436832112fac2943dee0f710a94fa6f3074e9e',
#    'commits': [{'sha': 'f79c082cd1445a8ec4dcda3603018fbbbcef4ca3',
#      'author': {'email': 'dragonkey100@gmail.com', 'name': 'Wai Yan Myint Mo'},
#      'message': "sorry I'll be gone for a while",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Stiles-X/console-menu/commits/f79c082cd1445a8ec4dcda3603018fbbbcef4ca3'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:00Z'},
#  {'id': '11037679248',
#   'type': 'PushEvent',
#   'actor': {'id': 32809689,
#    'login': 'galobtter',
#    'display_login': 'galobtter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/galobtter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32809689?'},
#   'repo': {'id': 203309816,
#    'name': 'galobtter/prosesize',
#    'url': 'https://api.github.com/repos/galobtter/prosesize'},
#   'payload': {'push_id': 4369410661,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '96d26dac9052c5c4513f54251d9ea3fdcdf4a112',
#    'before': 'f2767ba7bb9f294145e7f5fb4731bb4a0f07e6d6',
#    'commits': [{'sha': '96d26dac9052c5c4513f54251d9ea3fdcdf4a112',
#      'author': {'email': 'galobtter@gmail.com', 'name': 'Galobtter'},
#      'message': 'Tweak comment link',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/galobtter/prosesize/commits/96d26dac9052c5c4513f54251d9ea3fdcdf4a112'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:00Z'},
#  {'id': '11037679247',
#   'type': 'PushEvent',
#   'actor': {'id': 56762032,
#    'login': '201816040229',
#    'display_login': '201816040229',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/201816040229',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56762032?'},
#   'repo': {'id': 226635350,
#    'name': '201816040229/LabExercises_03',
#    'url': 'https://api.github.com/repos/201816040229/LabExercises_03'},
#   'payload': {'push_id': 4369410660,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '87387bd2ee6d5684360df358fbff1d8c1df01b29',
#    'before': '49de97c1590ca5c4386f252315687a1089ec4666',
#    'commits': [{'sha': '87387bd2ee6d5684360df358fbff1d8c1df01b29',
#      'author': {'email': '56762032+201816040229@users.noreply.github.com',
#       'name': '201816040229'},
#      'message': 'Create SavingAccount.h',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/201816040229/LabExercises_03/commits/87387bd2ee6d5684360df358fbff1d8c1df01b29'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:00Z'},
#  {'id': '11037679243',
#   'type': 'PushEvent',
#   'actor': {'id': 58103095,
#    'login': 'ShaillyJain8279',
#    'display_login': 'ShaillyJain8279',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShaillyJain8279',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58103095?'},
#   'repo': {'id': 226473970,
#    'name': 'ShaillyJain8279/SnakeGame-v1.0',
#    'url': 'https://api.github.com/repos/ShaillyJain8279/SnakeGame-v1.0'},
#   'payload': {'push_id': 4369410659,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '61be4c68d3b73329209bb5e0efc480d4f5130787',
#    'before': '4d154abe9525cf0a4a896053dd5e1d4b851340b8',
#    'commits': [{'sha': '61be4c68d3b73329209bb5e0efc480d4f5130787',
#      'author': {'email': '58103095+ShaillyJain8279@users.noreply.github.com',
#       'name': 'ShaillyJain8279'},
#      'message': 'updated source code',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ShaillyJain8279/SnakeGame-v1.0/commits/61be4c68d3b73329209bb5e0efc480d4f5130787'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:00Z'},
#  {'id': '11037679241',
#   'type': 'PushEvent',
#   'actor': {'id': 7979313,
#    'login': 'HussainAther',
#    'display_login': 'HussainAther',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HussainAther',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7979313?'},
#   'repo': {'id': 193165285,
#    'name': 'HussainAther/journalism',
#    'url': 'https://api.github.com/repos/HussainAther/journalism'},
#   'payload': {'push_id': 4369410653,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '28ebd81dc66100c878d34d4c3e1c70dc4436f527',
#    'before': 'df980df2b2585b587a4678ffc795dd60e460e694',
#    'commits': [{'sha': '28ebd81dc66100c878d34d4c3e1c70dc4436f527',
#      'author': {'email': 'shussainather@gmail.com',
#       'name': 'Syed Hussain Ather'},
#      'message': 'init',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HussainAther/journalism/commits/28ebd81dc66100c878d34d4c3e1c70dc4436f527'}]},
#   'public': True,
#   'created_at': '2019-12-08T08:18:00Z'},
#  {'id': '11037679240',
#   'type': 'WatchEvent',
#   'actor': {'id': 8246853,
#    'login': 'annaghi',
#    'display_login': 'annaghi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/annaghi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8246853?'},
#   'repo': {'id': 185633469,
#    'name': 'webbhuset/elm-actor-model',
#    'url': 'https://api.github.com/repos/webbhuset/elm-actor-model'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-08T08:18:00Z',
#   'org': {'id': 5766322,
#    'login': 'webbhuset',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/webbhuset',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5766322?'}},
#  {'id': '11037679239',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46594794,
#    'name': 'Lombiq/Associativy-Web-Services',
#    'url': 'https://api.github.com/repos/Lombiq/Associativy-Web-Services'},
#   'payload': {'push_id': 4369410657,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.10.1',
#    'head': '844b3cb5fb12a30f02e6bb415c6ce5c0b192ef34',
#    'before': '844b3cb5fb12a30f02e6bb415c6ce5c0b192ef34',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-08T08:18:00Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.get('https://cat-fact.herokuapp.com/facts')

# %%
print(type(json.loads(r.text)))
json.loads(r.text)
# Out:
# <class 'dict'>
# {'all': [{'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
#     'name': {'first': 'David', 'last': 'Gippner'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475ca8a99c3f00140fe4d0',
# ...
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de608922c455b00153df05d',
#    'type': 'cat',
#    'text': 'Coba cat nyata.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de6090e2c455b00153df05e',
#    'type': 'cat',
#    'text': 'Cats has no hands.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de609812c455b00153df05f',
#    'type': 'cat',
#    'text': 'Testing aja.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'More than half of the world’s felines don’t respond to catnip.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de7808a0013130015a3ccb0',
#    'type': 'cat',
#    'text': 'The wealthiest cat in the world is named Blackie.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780a00013130015a3ccb1',
#    'type': 'cat',
#    'text': 'A group of kittens is called a Kindle.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780d30013130015a3ccb2',
#    'type': 'cat',
#    'text': 'In October 1983, a cat named "Félicette" became the first cat in space.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780e60013130015a3ccb3',
#    'type': 'cat',
#    'text': 'Cats can be allergic to humans.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5deb725edeb28e00158cd804',
#    'type': 'cat',
#    'text': 'Cats are nuts.',
#    'user': {'_id': '5deb723adeb28e00158cd803',
#     'name': {'first': 'Trip Store', 'last': 'Krabi'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
print(type(json.loads(r.text)))
json.loads(r.text)
# Out:
# <class 'dict'>
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '2560H025',
#    'WaterLevel': 3.53},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': -999998},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': 261.61},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1730H036',
#    'WaterLevel': 107.45},
#   {'RecordTime': 'Dec 8, 2019 3:20:00 PM',
#    'StationIdentifier': '1630H033',
#    'WaterLevel': 0.21},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1850H004',
#    'WaterLevel': 72.06},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1650H015',
#    'WaterLevel': 0.15},
#   {'RecordTime': 'Dec 8, 2019 3:20:00 PM',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': 1.56},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1740H009',
#    'WaterLevel': 32.36},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': 5.66},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1630H025',
#    'WaterLevel': 1.43},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1740H008',
#    'WaterLevel': 1.11},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '2200H007',
#    'WaterLevel': 156.15},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': 12.8},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1630H018',
#    'WaterLevel': 10.01},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '2560H023',
#    'WaterLevel': 13.27},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': 2.99},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.31},
#   {'RecordTime': 'Dec 8, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H083',
#    'WaterLevel': 116.66},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1740H011',
#    'WaterLevel': 6.6},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1590H015',
#    'WaterLevel': 9.35},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '2560H017',
#    'WaterLevel': 366.39},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1580H022',
#    'WaterLevel': 0.21},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1650H012',
#    'WaterLevel': 0.71},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1510H080',
#    'WaterLevel': 1068.95},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1730H077',
#    'WaterLevel': 740.49},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '2200H022',
#    'WaterLevel': 161.02},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1660H010',
#    'WaterLevel': 7.51},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1580H015',
#    'WaterLevel': 22.55},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': 380.48},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1650H008',
#    'WaterLevel': 0.59},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1510H079',
#    'WaterLevel': 187.7},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': 248.9},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': 65.85},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1650H010',
#    'WaterLevel': 0.29},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1680H004',
#    'WaterLevel': 1.08},
#   {'RecordTime': 'Dec 8, 2019 3:20:00 PM',
#    'StationIdentifier': '1630H031',
#    'WaterLevel': 0.5},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '2200H020',
#    'WaterLevel': 318.17},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1550H016',
#    'WaterLevel': 12.32},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.23},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1430H029',
#    'WaterLevel': 50.59},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1630H040',
#    'WaterLevel': 1.81},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': 20.68},
#   {'RecordTime': 'Dec 8, 2019 3:20:00 PM',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': 26.19},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': 39.76},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1540H035',
#    'WaterLevel': 86.8},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': 0.13},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': 639.41},
#   {'RecordTime': 'Dec 8, 2019 3:20:00 PM',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': 278.44},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1430H058',
#    'WaterLevel': 83.01},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1630H023',
#    'WaterLevel': 0.22},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1580H018',
#    'WaterLevel': 21.22},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': 27.17},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1540H039',
#    'WaterLevel': 38.99},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1580H008',
#    'WaterLevel': 19.43},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1510H058',
#    'WaterLevel': 12.31},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1340H014',
#    'WaterLevel': 0.3},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1430H053',
#    'WaterLevel': 38.42},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': 624.94},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': -0.14},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': 31.93},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1550H017',
#    'WaterLevel': 15.76},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1510H049',
#    'WaterLevel': 470.87},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1340H011',
#    'WaterLevel': 7.39},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1430H051',
#    'WaterLevel': 95.73},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1400H009',
#    'WaterLevel': 191.53},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1510H088',
#    'WaterLevel': 141.11},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': 20.21},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1420H053',
#    'WaterLevel': 471.6},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': 79.82},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1320H001',
#    'WaterLevel': 2.66},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1430H047',
#    'WaterLevel': 72.35},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1510H086',
#    'WaterLevel': 317.97},
#   {'RecordTime': 'Dec 8, 2019 3:55:00 PM',
#    'StationIdentifier': '1140H108',
#    'WaterLevel': 12.49},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': -0.35},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1420H049',
#    'WaterLevel': 54.19},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': 91.59},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1300H023',
#    'WaterLevel': 52.32},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1420H058',
#    'WaterLevel': 440.47},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1510H075',
#    'WaterLevel': 346.46},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1140H082',
#    'WaterLevel': 7.25},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1350H028',
#    'WaterLevel': 232.68},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1400H019',
#    'WaterLevel': 310.14},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1430H040',
#    'WaterLevel': 19.46},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1300H020',
#    'WaterLevel': 251.5},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': 318.95},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': 282.07},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1140H049',
#    'WaterLevel': 22.16},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1350H024',
#    'WaterLevel': 259.7},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1350H025',
#    'WaterLevel': 0.59},
#   {'RecordTime': 'Dec 8, 2019 3:40:00 AM',
#    'StationIdentifier': '1300H016',
#    'WaterLevel': -999998},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1300H022',
#    'WaterLevel': -1.36},
#   {'RecordTime': 'Dec 8, 2019 3:55:00 PM',
#    'StationIdentifier': '1140H106',
#    'WaterLevel': 49.14},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1350H001',
#    'WaterLevel': 169.87},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': 164.36},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1350H020',
#    'WaterLevel': 220.8},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1350H022',
#    'WaterLevel': 253.97},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1730H065',
#    'WaterLevel': 90.72},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1290H002',
#    'WaterLevel': 41.05},
#   {'RecordTime': 'Dec 8, 2019 3:50:00 PM',
#    'StationIdentifier': '1140H099',
#    'WaterLevel': 263.77}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
