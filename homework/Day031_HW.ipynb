# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
# 沒有加 header
url = "https://www.zhihu.com/special/19681091"
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
soup
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr/><center>openresty</center>
# </body>
# </html>

# %%
# 有加 header
url = "https://www.zhihu.com/special/19681091"
headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
resp = requests.get(url, headers=headers)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html data-theme="light" lang="zh"><head><meta charset="utf-8"/><title data-react-helmet="true">知乎实时：关于新冠肺炎你需要知道的 - 知乎</title><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0, viewport-fit=cover" name="viewport"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><title>知乎</title><link crossorigin="" href="https://static.zhihu.com/special-webapp/static/css/4.chunk.73684a2a.css" rel="stylesheet"/><link crossorigin="" href="https://static.zhihu.com/special-webapp/static/css/client.chunk.ff3062ff.css" rel="stylesheet"/><script crossorigin="" defer="" src="https://static.zhihu.com/special-webapp/static/js/runtime~client.a0f1278f.js"></script><script crossorigin="" defer="" src="https://static.zhihu.com/special-webapp/static/js/4.chunk.4a68b3d3.js"></script><script crossorigin="" defer="" src="https://static.zhihu.com/special-webapp/static/js/client.chunk.e3f48aa4.js"></script><style>
# .u-statusBarPlaceholder {
#   height: constant(safe-area-inset-top);
#   height: env(safe-area-inset-top);
# }
#
# .u-tabPanelPlaceholder {
#   height: constant(safe-area-inset-bottom);
#   height: env(safe-area-inset-bottom);
# }
# </style></head><body><div id="root"><div class="FixedLayer-module-root-3Xdm" id="fixed-layer"></div><div><header class="Sticky MobileAppHeader" style="line-height:50px"><div class="MobileAppHeader-inner MobileAppHeader-innerWithoutSearchHeader"><a aria-label="知乎" class="MobileAppHeader-logo" href="//www.zhihu.com?utm_source=zhihu&amp;utm_campaign=guest_feed&amp;utm_content=guide"><svg fill="#0084FF" height="30" viewbox="0 0 200 91" width="64"><path d="M53.29 80.035l7.32.002 2.41 8.24 13.128-8.24h15.477v-67.98H53.29v67.978zm7.79-60.598h22.756v53.22h-8.73l-8.718 5.473-1.587-5.46-3.72-.012v-53.22zM46.818 43.162h-16.35c.545-8.467.687-16.12.687-22.955h15.987s.615-7.05-2.68-6.97H16.807c1.09-4.1 2.46-8.332 4.1-12.708 0 0-7.523 0-10.085 6.74-1.06 2.78-4.128 13.48-9.592 24.41 1.84-.2 7.927-.37 11.512-6.94.66-1.84.785-2.08 1.605-4.54h9.02c0 3.28-.374 20.9-.526 22.95H6.51c-3.67 0-4.863 7.38-4.863 7.38H22.14C20.765 66.11 13.385 79.24 0 89.62c6.403 1.828 12.784-.29 15.937-3.094 0 0 7.182-6.53 11.12-21.64L43.92 85.18s2.473-8.402-.388-12.496c-2.37-2.788-8.768-10.33-11.496-13.064l-4.57 3.627c1.363-4.368 2.183-8.61 2.46-12.71H49.19s-.027-7.38-2.372-7.38zm128.752-.502c6.51-8.013 14.054-18.302 14.054-18.302s-5.827-4.625-8.556-1.27c-1.874 2.548-11.51 15.063-11.51 15.063l6.012 4.51zm-46.903-18.462c-2.814-2.577-8.096.667-8.096.667s12.35 17.2 12.85 17.953l6.08-4.29s-8.02-11.752-10.83-14.33zM199.99 46.5c-6.18 0-40.908.292-40.953.292v-31.56c1.503 0 3.882-.124 7.14-.376 12.773-.753 21.914-1.25 27.427-1.504 0 0 3.817-8.496-.185-10.45-.96-.37-7.24 1.43-7.24 1.43s-51.63 5.153-72.61 5.64c.5 2.756 2.38 5.336 4.93 6.11 4.16 1.087 7.09.53 15.36.277 7.76-.5 13.65-.76 17.66-.76v31.19h-41.71s.88 6.97 7.97 7.14h33.73v22.16c0 4.364-3.498 6.87-7.65 6.6-4.4.034-8.15-.36-13.027-.566.623 1.24 1.977 4.496 6.035 6.824 3.087 1.502 5.054 2.053 8.13 2.053 9.237 0 14.27-5.4 14.027-14.16V53.93h38.235c3.026 0 2.72-7.432 2.72-7.432z" fill-rule="evenodd"></path></svg></a><div class="MobileAppHeader-inner"><div class="MobileAppHeader-actions"><a class="MobileAppHeader-downloadLink" data-za-detail-view-name="下载 App" href="https://www.zhihu.com/app?auto_download=true&amp;utm_source=zhihu&amp;utm_campaign=guest_feed&amp;utm_content=guide">下载 App</a><a class="MobileAppHeader-authLink" data-za-detail-view-name="注册或登录" href="https://www.zhihu.com/signin?next=/">注册登录</a></div></div></div><div></div></header></div><style data-emotion-css="scxyie">.css-scxyie{max-width:640px;min-height:100vh;margin:0 auto;}</style><div class="fxGrayscale css-scxyie"><style data-emotion-css="1s1trdk">.css-1s1trdk{position:relative;padding-bottom:47.199999999999996%;height:0;}</style><style data-emotion-css="1ks7czt">.css-1ks7czt{box-sizing:border-box;margin:0;min-width:0;position:relative;padding-bottom:47.199999999999996%;height:0;}</style><div class="css-1ks7czt"><style data-emotion-css="122y91a">.css-122y91a{position:absolute;top:0;left:0;width:100%;height:100%;}</style><div class="css-122y91a"><style data-emotion-css="1phd9a0">.css-1phd9a0{object-fit:cover;}</style><style data-emotion-css="uxsm0w">.css-uxsm0w{box-sizing:border-box;margin:0;min-width:0;max-width:100%;height:auto;width:100%;height:100%;object-fit:cover;}</style><img alt="banner" class="css-uxsm0w" src="https://pic3.zhimg.com/100/v2-19c82c82f5b13c63ea5fbf26c93eccb6_fhd.png"/><style data-emotion-css="1h9y955">.css-1h9y955{position:absolute;right:0;bottom:0;left:0;top:0;background-image:linear-gradient(to bottom,rgba(0,0,0,0) 50%,rgba(0,0,0,0.5) 100%);border-radius:inherit;pointer-events:none;}</style><style data-emotion-css="7yumqj">.css-7yumqj{box-sizing:border-box;margin:0;min-width:0;position:absolute;right:0;bottom:0;left:0;top:0;background-image:linear-gradient(to bottom,rgba(0,0,0,0) 50%,rgba(0,0,0,0.5) 100%);border-radius:inherit;pointer-events:none;}</style><div class="css-7yumqj"></div><style data-emotion-css="1yu6a0v">.css-1yu6a0v{position:absolute;bottom:40px;left:0;right:0;}</style><style data-emotion-css="1c5atzx">.css-1c5atz ...
# if (window.AppViewBridge && typeof AppViewBridge.webPageReady === 'function') {
#   AppViewBridge.webPageReady();
# }
# if (window.zhihuNativeApp && window.zhihuNativeApp.webPageReady) {
#   window.zhihuNativeApp.webPageReady();
# }
# </script></body></html>

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# 比較保險的⽅式是把所有欄位補上去，但 user-agent 通常是最基本的篩選條件，故可以先大膽假設用這個欄位
